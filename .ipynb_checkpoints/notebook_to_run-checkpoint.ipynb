# %%
# %matplotlib inline
# %run ./py/commTest.py
# Out:
# output/eps/cross_latex.tex
# Including dipolar H2 C1
# Including dipolar H3 C1
# Including dipolar H4 C1
# Including dipolar H6 C5
# Including dipolar H7 C5
# Including dipolar H8 C5
# Including dipolar H2 H3
# Including dipolar H2 H4
# Including dipolar H3 H4
# Including dipolar H6 H7
# Including dipolar H6 H8
# Including dipolar H7 H8
# Including CSA H2
# Including CSA H3
# Including CSA H4
# Including CSA H6
# Including CSA H7
# Including CSA H8
# Including CSA C1
# Including CSA C5
# Including dipolar H2 H6
# Including dipolar H2 H7
# Including dipolar H2 H8
# Including dipolar H3 H6
# Including dipolar H3 H7
# Including dipolar H3 H8
# Including dipolar H4 H6
# Including dipolar H4 H7
# Including dipolar H4 H8
# Library entries to evaluate: 16941
# NUMBER OF PEAKS INCLUDED IN OPTIMIZATION:  10
# NUMBER OF RESIDUES INCLUDED IN WOBBLE-MASK: 4.0
# NUMBER OF PEAKS INCLUDED IN DATA SET MASK: 15
# input/1EZA_test
# count_leu =  0
# count_val =  0
# count_ile =  3
# count_ala =  2
# ...

# %%
def methyl_list_generator(residue_list):
    #EXAMPLES OF RESIDUE NAMES:
    #'ILE   57', 'LEU  123', 'VAL  176'
    methyl_list=[]
    for residue in residue_list:
        if(residue[0:3]=='ILE' or residue[0:3]=='ALA'):
            methyl_list.append(residue+' A')
        if(residue[0:3]=='VAL' or residue[0:3]=='LEU'):
            ab = random.choice([' A', ' B'])
            methyl_list.append(residue+ab)
#         print 'METHYL LIST = \n',methyl_list
    return methyl_list


def methyl_list_generator(self,residue_list):#Will also take self.map_key_xrd
    index_array=numpy.zeros((self.num_samples,len(num_residues)))
    pair_array=numpy.zeros((len(num_residues),2))
    for i in len(residue_list):
        residue=residue_list[i]
        if(residue[0:3]=='ILE' or residue[0:3]=='ALA'):
            pair_array[i,:]=self.map_key_nmr[residue+' A']
        if(residue[0:3]=='VAL' or residue[0:3]=='LEU'):
            pair_array[i,0]=self.map_key_nmr[residue+' A']
            pair_array[i,1]=self.map_key_nmr[residue+' B']
    index_list=numpy.zeros(len(self.num_samples))
    index_list[0:num_samples/2],index_list[num_samples/2:]=0
    for i in len(residue_list):
        numpy.random.shuffle(index_list)
        
        
residue_list=['LEU  123', 'VAL  176','VAL  175']
a_cnt,b_cnt,c_cnt=0.,0.,0.
num=2000
for i in range(num):
    a,b,c=methyl_list_generator(residue_list)
    if(a[-1]=='A'):
        a_cnt+=1
    if(b[-1]=='A'):
        b_cnt+=1
    if(c[-1]=='A'):
        c_cnt+=1
exp=num/2.
print a_cnt,(a_cnt-exp)/exp*100.
print b_cnt,(b_cnt-exp)/exp*100.
print c_cnt,(c_cnt-exp)/exp*100.
# Out:
# 1004.0 0.4
# 1001.0 0.1
# 979.0 -2.1

# %%
# %matplotlib inline
# %run ./py/commTest.py
# Out:
# output/eps/cross_latex.tex
# Including dipolar H2 C1
# Including dipolar H3 C1
# Including dipolar H4 C1
# Including dipolar H6 C5
# Including dipolar H7 C5
# Including dipolar H8 C5
# Including dipolar H2 H3
# Including dipolar H2 H4
# Including dipolar H3 H4
# Including dipolar H6 H7
# Including dipolar H6 H8
# Including dipolar H7 H8
# Including CSA H2
# Including CSA H3
# Including CSA H4
# Including CSA H6
# Including CSA H7
# Including CSA H8
# Including CSA C1
# Including CSA C5
# Including dipolar H2 H6
# Including dipolar H2 H7
# Including dipolar H2 H8
# Including dipolar H3 H6
# Including dipolar H3 H7
# Including dipolar H3 H8
# Including dipolar H4 H6
# Including dipolar H4 H7
# Including dipolar H4 H8
# Library entries to evaluate: 16941
# NUMBER OF PEAKS INCLUDED IN OPTIMIZATION:  200
# NUMBER OF RESIDUES INCLUDED IN WOBBLE-MASK: 70.0
# NUMBER OF PEAKS INCLUDED IN DATA SET MASK: 463
# input/1EZA
# count_leu =  29
# count_val =  17
# count_ile =  24
# count_ala =  30
# ...

# %%
# %matplotlib inline
# %run ./py/commTest.py
# Out:
# output/eps/cross_latex.tex
# Including dipolar H2 C1
# Including dipolar H3 C1
# Including dipolar H4 C1
# Including dipolar H6 C5
# Including dipolar H7 C5
# Including dipolar H8 C5
# Including dipolar H2 H3
# Including dipolar H2 H4
# Including dipolar H3 H4
# Including dipolar H6 H7
# Including dipolar H6 H8
# Including dipolar H7 H8
# Including CSA H2
# Including CSA H3
# Including CSA H4
# Including CSA H6
# Including CSA H7
# Including CSA H8
# Including CSA C1
# Including CSA C5
# Including dipolar H2 H6
# Including dipolar H2 H7
# Including dipolar H2 H8
# Including dipolar H3 H6
# Including dipolar H3 H7
# Including dipolar H3 H8
# Including dipolar H4 H6
# Including dipolar H4 H7
# Including dipolar H4 H8
# Library entries to evaluate: 16941
# NUMBER OF PEAKS INCLUDED IN OPTIMIZATION:  200
# NUMBER OF RESIDUES INCLUDED IN WOBBLE-MASK: 70.0
# NUMBER OF PEAKS INCLUDED IN DATA SET MASK: 463
# input/1EZA
# count_leu =  29
# count_val =  17
# count_ile =  24
# count_ala =  30
# ...

# %%
# %matplotlib inline
# %run ./py/commTest.py
# Out:
# output/eps/cross_latex.tex
# Including dipolar H2 C1
# Including dipolar H3 C1
# Including dipolar H4 C1
# Including dipolar H6 C5
# Including dipolar H7 C5
# Including dipolar H8 C5
# Including dipolar H2 H3
# Including dipolar H2 H4
# Including dipolar H3 H4
# Including dipolar H6 H7
# Including dipolar H6 H8
# Including dipolar H7 H8
# Including CSA H2
# Including CSA H3
# Including CSA H4
# Including CSA H6
# Including CSA H7
# Including CSA H8
# Including CSA C1
# Including CSA C5
# Including dipolar H2 H6
# Including dipolar H2 H7
# Including dipolar H2 H8
# Including dipolar H3 H6
# Including dipolar H3 H7
# Including dipolar H3 H8
# Including dipolar H4 H6
# Including dipolar H4 H7
# Including dipolar H4 H8
# Library entries to evaluate: 16941
# NUMBER OF PEAKS INCLUDED IN OPTIMIZATION:  200
# NUMBER OF RESIDUES INCLUDED IN WOBBLE-MASK: 70.0
# NUMBER OF PEAKS INCLUDED IN DATA SET MASK: 463
# input/1EZA
# count_leu =  29
# count_val =  17
# count_ile =  24
# count_ala =  30
# ...

# %%
# %matplotlib inline
# %run ./py/commTest.py
# Out:
# output/eps/cross_latex.tex
# Including dipolar H2 C1
# Including dipolar H3 C1
# Including dipolar H4 C1
# Including dipolar H6 C5
# Including dipolar H7 C5
# Including dipolar H8 C5
# Including dipolar H2 H3
# Including dipolar H2 H4
# Including dipolar H3 H4
# Including dipolar H6 H7
# Including dipolar H6 H8
# Including dipolar H7 H8
# Including CSA H2
# Including CSA H3
# Including CSA H4
# Including CSA H6
# Including CSA H7
# Including CSA H8
# Including CSA C1
# Including CSA C5
# Including dipolar H2 H6
# Including dipolar H2 H7
# Including dipolar H2 H8
# Including dipolar H3 H6
# Including dipolar H3 H7
# Including dipolar H3 H8
# Including dipolar H4 H6
# Including dipolar H4 H7
# Including dipolar H4 H8
# Library entries to evaluate: 16941
# NUMBER OF PEAKS INCLUDED IN OPTIMIZATION:  200
# NUMBER OF RESIDUES INCLUDED IN WOBBLE-MASK: 70.0
# NUMBER OF PEAKS INCLUDED IN DATA SET MASK: 463
# input/1EZA
# count_leu =  29
# count_val =  17
# count_ile =  24
# count_ala =  30
# ...

# %%
# %matplotlib inline
# %run ./py/commTest.py
# Out:
# output/eps/cross_latex.tex
# Including dipolar H2 C1
# Including dipolar H3 C1
# Including dipolar H4 C1
# Including dipolar H6 C5
# Including dipolar H7 C5
# Including dipolar H8 C5
# Including dipolar H2 H3
# Including dipolar H2 H4
# Including dipolar H3 H4
# Including dipolar H6 H7
# Including dipolar H6 H8
# Including dipolar H7 H8
# Including CSA H2
# Including CSA H3
# Including CSA H4
# Including CSA H6
# Including CSA H7
# Including CSA H8
# Including CSA C1
# Including CSA C5
# Including dipolar H2 H6
# Including dipolar H2 H7
# Including dipolar H2 H8
# Including dipolar H3 H6
# Including dipolar H3 H7
# Including dipolar H3 H8
# Including dipolar H4 H6
# Including dipolar H4 H7
# Including dipolar H4 H8
# Library entries to evaluate: 16941
# NUMBER OF PEAKS INCLUDED IN OPTIMIZATION:  200
# NUMBER OF RESIDUES INCLUDED IN WOBBLE-MASK: 70.0
# NUMBER OF PEAKS INCLUDED IN DATA SET MASK: 463
# input/1EZA
# count_leu =  29
# count_val =  17
# count_ile =  24
# count_ala =  30
# ...

# %%
# %matplotlib inline
# %run ./py/commTest.py
# Out:
# output/eps/cross_latex.tex
# Including dipolar H2 C1
# Including dipolar H3 C1
# Including dipolar H4 C1
# Including dipolar H6 C5
# Including dipolar H7 C5
# Including dipolar H8 C5
# Including dipolar H2 H3
# Including dipolar H2 H4
# Including dipolar H3 H4
# Including dipolar H6 H7
# Including dipolar H6 H8
# Including dipolar H7 H8
# Including CSA H2
# Including CSA H3
# Including CSA H4
# Including CSA H6
# Including CSA H7
# Including CSA H8
# Including CSA C1
# Including CSA C5
# Including dipolar H2 H6
# Including dipolar H2 H7
# Including dipolar H2 H8
# Including dipolar H3 H6
# Including dipolar H3 H7
# Including dipolar H3 H8
# Including dipolar H4 H6
# Including dipolar H4 H7
# Including dipolar H4 H8
# Library entries to evaluate: 16941
# NUMBER OF PEAKS INCLUDED IN OPTIMIZATION:  200
# NUMBER OF RESIDUES INCLUDED IN WOBBLE-MASK: 70.0
# NUMBER OF PEAKS INCLUDED IN DATA SET MASK: 463
# input/1EZA
# count_leu =  29
# count_val =  17
# count_ile =  24
# count_ala =  30
# ...

# %%
# %matplotlib inline
# %run ./py/commTest.py
# Out:
# output/eps/cross_latex.tex
# Including dipolar H2 C1
# Including dipolar H3 C1
# Including dipolar H4 C1
# Including dipolar H6 C5
# Including dipolar H7 C5
# Including dipolar H8 C5
# Including dipolar H2 H3
# Including dipolar H2 H4
# Including dipolar H3 H4
# Including dipolar H6 H7
# Including dipolar H6 H8
# Including dipolar H7 H8
# Including CSA H2
# Including CSA H3
# Including CSA H4
# Including CSA H6
# Including CSA H7
# Including CSA H8
# Including CSA C1
# Including CSA C5
# Including dipolar H2 H6
# Including dipolar H2 H7
# Including dipolar H2 H8
# Including dipolar H3 H6
# Including dipolar H3 H7
# Including dipolar H3 H8
# Including dipolar H4 H6
# Including dipolar H4 H7
# Including dipolar H4 H8
# Library entries to evaluate: 16941
# NUMBER OF PEAKS INCLUDED IN OPTIMIZATION:  200
# NUMBER OF RESIDUES INCLUDED IN WOBBLE-MASK: 70.0
# NUMBER OF PEAKS INCLUDED IN DATA SET MASK: 463
# input/1EZA
# count_leu =  29
# count_val =  17
# count_ile =  24
# count_ala =  30
# ...

# %%
# %matplotlib inline
# %run ./py/commTest.py
# Out:
# output/eps/cross_latex.tex
# Including dipolar H2 C1
# Including dipolar H3 C1
# Including dipolar H4 C1
# Including dipolar H6 C5
# Including dipolar H7 C5
# Including dipolar H8 C5
# Including dipolar H2 H3
# Including dipolar H2 H4
# Including dipolar H3 H4
# Including dipolar H6 H7
# Including dipolar H6 H8
# Including dipolar H7 H8
# Including CSA H2
# Including CSA H3
# Including CSA H4
# Including CSA H6
# Including CSA H7
# Including CSA H8
# Including CSA C1
# Including CSA C5
# Including dipolar H2 H6
# Including dipolar H2 H7
# Including dipolar H2 H8
# Including dipolar H3 H6
# Including dipolar H3 H7
# Including dipolar H3 H8
# Including dipolar H4 H6
# Including dipolar H4 H7
# Including dipolar H4 H8
# Library entries to evaluate: 16941
# NUMBER OF PEAKS INCLUDED IN OPTIMIZATION:  200
# NUMBER OF RESIDUES INCLUDED IN WOBBLE-MASK: 70.0
# NUMBER OF PEAKS INCLUDED IN DATA SET MASK: 463
# input/1EZA
# count_leu =  29
# count_val =  17
# count_ile =  24
# count_ala =  30
# ...

# %%
# %matplotlib inline
# %run ./py/commTest.py
# Out:
# output/eps/cross_latex.tex
# Including dipolar H2 C1
# Including dipolar H3 C1
# Including dipolar H4 C1
# Including dipolar H6 C5
# Including dipolar H7 C5
# Including dipolar H8 C5
# Including dipolar H2 H3
# Including dipolar H2 H4
# Including dipolar H3 H4
# Including dipolar H6 H7
# Including dipolar H6 H8
# Including dipolar H7 H8
# Including CSA H2
# Including CSA H3
# Including CSA H4
# Including CSA H6
# Including CSA H7
# Including CSA H8
# Including CSA C1
# Including CSA C5
# Including dipolar H2 H6
# Including dipolar H2 H7
# Including dipolar H2 H8
# Including dipolar H3 H6
# Including dipolar H3 H7
# Including dipolar H3 H8
# Including dipolar H4 H6
# Including dipolar H4 H7
# Including dipolar H4 H8
# Library entries to evaluate: 16941
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 100

# %%
num_arr=numpy.array([1,10,100,250,500,1000,1500,2000,3000,4000,5000,7500,10000,15000,20000,25000,40000,50000])
compare_list=numpy.array([1.1420436725660252e+01, 1.5575933961064243e+00, 9.3687171455412332e-02,
 3.3578390615367507e-02, 2.9224343921464450e-02, 1.2355426025220599e-02,
 8.8063761729718047e-03, 5.8457256831471131e-03, 3.1306456333774031e-03,
 2.2475330372708092e-03, 1.7528817093882937e-03, 1.1805649829793579e-03,
 6.5327253145785775e-04, 3.3724208275539061e-04, 3.0373954292256826e-04,
 2.3045382980654090e-04, 5.4520298121194872e-05, 0.0000000000000000e+00])

plt.scatter(num_arr[2:],compare_list[2:])
plt.xlabel("Number of samples")
plt.ylabel("chi**2 - Deviation from converged result")
plt.title("Convergence dependent on sampling rate")
plt.savefig('output/figs/convergence_plt',dpi=900)
plt.show()

# %%
# %matplotlib inline
# %run ./py/commTest.py
# Out:
# output/eps/cross_latex.tex
# Including dipolar H2 C1
# Including dipolar H3 C1
# Including dipolar H4 C1
# Including dipolar H6 C5
# Including dipolar H7 C5
# Including dipolar H8 C5
# Including dipolar H2 H3
# Including dipolar H2 H4
# Including dipolar H3 H4
# Including dipolar H6 H7
# Including dipolar H6 H8
# Including dipolar H7 H8
# Including CSA H2
# Including CSA H3
# Including CSA H4
# Including CSA H6
# Including CSA H7
# Including CSA H8
# Including CSA C1
# Including CSA C5
# Including dipolar H2 H6
# Including dipolar H2 H7
# Including dipolar H2 H8
# Including dipolar H3 H6
# Including dipolar H3 H7
# Including dipolar H3 H8
# Including dipolar H4 H6
# Including dipolar H4 H7
# Including dipolar H4 H8
# Library entries to evaluate: 16941
# NUMBER OF PEAKS INCLUDED IN OPTIMIZATION:  200
# NUMBER OF RESIDUES INCLUDED IN WOBBLE-MASK: 70.0
# NUMBER OF PEAKS INCLUDED IN DATA SET MASK: 463
# input/1EZA.pdb
# count_leu =  29
# count_val =  17
# count_ile =  24
# ...
