# %%
import numpy

def color_calc(frac):
    r,g,b=0.,0.,0.
    r=0.5*(-frac+1.)
    b=0.5*(1.+frac)
#     r=frac
#     b=1.-frac
    return r,g,b

def frac_calc(nmr,xrd):
    hypo=numpy.sqrt(nmr**2 + xrd**2) #Calculate "hypotenuse" to normalize fraction to -1<x<1
    frac=(nmr-xrd)/nmr
    return frac


file=open('input','r')
store=[]
for line in file:
    store.append(line)
file.close()

diag_peaks={}
for data in store:
    typ,ident,letter,nmr,xrd=data.split()[0],int(data.split()[1]),data.split()[2],float(data.split()[3]),float(data.split()[4])
    tag=typ+' '+str(ident)+' '+letter
    diag_peaks[tag]=(nmr,xrd)
    if(nmr!=0. and xrd!=0.):
        print tag,'\t',(nmr-xrd)/nmr

write=open('output','w')
file=open('1EZA.pdb')
atom_list=[]
for line in file:
    if(line[0:4]=='ATOM'):
        atom_number = line[6:12]
        atom_name = line[13:16]
        residue_name = line[17:20]
        residue_number = int(line[22:26].strip())
        x_coord = float(line[30:38])
        y_coord = float(line[38:46])
        z_coord = float(line[46:54])

        atom={}
        atom['num']=atom_number
        atom['ele']=atom_name
        atom['residue']=residue_name+' '+str(residue_number)
        atom['x'], atom['y'], atom['z']=x_coord,y_coord,z_coord
        atom_list.append(atom)
#Now iterate over all atoms in atom_list and group in residue (type & number):
residue_list=[]
for atom in atom_list:
    if((atom['residue']+' A') in residue_list):
        pass
    else:
        if((atom['residue'][0:3]=='LEU') or (atom['residue'][0:3]=='VAL')):
            residue_list.append(atom['residue']+' A')
            residue_list.append(atom['residue']+' B')
        else:
            residue_list.append(atom['residue']+' A')
compare_file=open('compare_file_2','w')
for residue in residue_list:
    i=int(residue.split()[1])
    r,g,b=0.2,0.2,0.2
    if(residue in diag_peaks):
        print 'ENTERED LOOP'
        r_a,g_a,b_a=0.2,0.2,0.2
        r_b,g_b,b_b=0.2,0.2,0.2
        resa,resb=residue[:-1]+'A',residue[:-1]+'B'
        try:
            nmr_a,xrd_a=diag_peaks[resa]
            r_a,g_a,b_a=color_calc(frac_calc(nmr_a,xrd_a))
            nmr_b,xrd_b=diag_peaks[resb]
            r_b,g_b,b_b=color_calc(frac_calc(nmr_b,xrd_b))
            r,g,b=(r_a+r_b)/2.,(g_a+g_b)/2.,(b_a+b_b)/2.
            write.write('set_color color%i = [%.2f,%.2f,%.2f]\n'%(i,r,g,b))
            write.write('color color%i, resi %i\n'%(i,i))
            compare_file.write('%i\t%.2f\n'%(i,(frac_calc(nmr_a,xrd_a)+frac_calc(nmr_b,xrd_b))/2.))
            print residue,resa,resb
            continue
        except:
            pass
        try:
            nmr_a,xrd_a=diag_peaks[resa]
            r_a,g_a,b_a=color_calc(frac_calc(nmr_a,xrd_a))
            r,g,b=r_a,g_a,b_a
            write.write('set_color color%i = [%.2f,%.2f,%.2f]\n'%(i,r,g,b))
            write.write('color color%i, resi %i\n'%(i,i))
            compare_file.write('%i\t%.2f\n'%(i,frac_calc(nmr_a,xrd_a)))
            print residue
            continue
        except:
            pass
        try:
            nmr_b,xrd_b=diag_peaks[resb]
            r_b,g_b,b_b=color_calc(frac_calc(nmr_b,xrd_b))
            r,g,b=r_b,g_b,b_b
            write.write('set_color color%i = [%.2f,%.2f,%.2f]\n'%(i,r,g,b))
            write.write('color color%i, resi %i\n'%(i,i))
            compare_file.write('%i\t%.2f\n'%(i,frac_calc(nmr_b,xrd_b)))
            print residue
            continue
        except:
            pass
    print residue,'WRITING GREY: '        
    write.write('set_color color%i = [%.2f,%.2f,%.2f]\n'%(i,r,g,b))
    write.write('color color%i, resi %i\n'%(i,i))
write.close()
compare_file.close()
# Out:
# ALA 169 A 	0.989053548763
# ALA 194 A 	-5.26437208389
# ILE 152 A 	-0.767370826836
# ILE 108 A 	-1.07049418605
# LEU 218 B 	0.437021552098
# LEU 218 A 	0.635424056396
# LEU 18 A 	0.107631216402
# LEU 18 B 	-0.370246722239
# LEU 149 B 	0.444812347708
# LEU 149 A 	0.000685471554706
# ILE 90 A 	-1.58266971159
# ALA 241 A 	0.951743573443
# VAL 235 B 	0.851327134806
# VAL 235 A 	0.542689424727
# LEU 118 A 	0.205547157832
# LEU 118 B 	-0.098725688403
# LEU 79 B 	0.470443138026
# LEU 79 A 	0.0677097825348
# LEU 44 B 	0.0748591353499
# LEU 44 A 	0.959405909554
# ALA 61 A 	0.987928693009
# LEU 92 B 	-0.612156520283
# LEU 92 A 	0.963247833245
# ALA 127 A 	0.719569521802
# VAL 159 B 	0.698034430858
# VAL 208 B 	0.602743364378
# VAL 208 A 	-0.413086504179
# ALA 16 A 	0.841151831787
# ALA 160 A 	0.723700525497
# VAL 36 A 	0.875990181626
# VAL 36 B 	0.873941938599
# LEU 17 B 	-0.766833982839
# ALA 71 A 	-0.436848434915
# LEU 17 A 	0.217990064674
# VAL 212 B 	0.954736409131
# VAL 159 A 	0.924678178209
# LEU 19 A 	0.803942440264
# LEU 19 B 	-0.765583161177
# VAL 40 B 	0.80801264694
# ALA 114 A 	0.218551102388
# LEU 138 B 	0.677422875281
# LEU 138 A 	-0.036459928606
# ALA 12 A 	0.93321125363
# VAL 130 A 	0.948032397695
# VAL 130 B 	0.964221338162
# ILE 77 A 	-1.27671118134
# LEU 80 B 	-0.0533832820424
# LEU 163 B 	0.613551813638
# LEU 163 A 	0.744027459812
# ALA 183 A 	-1.13323045638
# LEU 220 B 	0.635116563566
# ALA 247 A 	0.4422687467
# ALA 102 A 	-2.63397774334
# ILE 219 A 	0.568458101985
# VAL 203 A 	0.908915484173
# VAL 203 B 	0.959021158679
# LEU 142 A 	-2.34580540696
# ILE 133 A 	0.976857714839
# ILE 26 A 	-0.337494681025
# ILE 141 A 	0.83627928164
# VAL 156 A 	-2.0527976009
# VAL 156 B 	-2.57273236888
# VAL 246 A 	0.387768930583
# VAL 246 B 	0.634064712848
# ALA 161 A 	0.470573320454
# VAL 40 A 	0.805511713933
# ALA 104 A 	0.593902999157
# ILE 180 A 	0.784948483063
# ILE 11 A 	0.343421744134
# VAL 212 A 	0.944151758055
# VAL 227 B 	0.263519761972
# VAL 227 A 	0.487847323693
# ILE 202 A 	0.407084175456
# LEU 123 B 	0.478478464436
# VAL 229 A 	0.980676192573
# ALA 103 A 	0.750572777255
# VAL 229 B 	-0.843104809898
# LEU 158 A 	0.846583428186
# ILE 31 A 	0.855684464143
# LEU 158 B 	0.494862515522
# VAL 223 B 	-0.271668457059
# VAL 223 A 	0.293436508097
# ILE 236 A 	-2.47924456827
# LEU 199 B 	-1.41474334419
# ILE 93 A 	0.632060679782
# LEU 6 A 	0.459264930559
# VAL 242 A 	0.360672717018
# VAL 242 B 	0.974724876508
# VAL 176 B 	-1.20018875598
# VAL 176 A 	-2.74748955791
# ILE 157 A 	0.820908114935
# ALA 151 A 	-0.155734793898
# LEU 85 B 	0.0742231398479
# LEU 85 A 	0.972897673802
# LEU 137 A 	0.639889894619
# LEU 137 B 	-0.627981208432
# ALA 33 A 	0.846535346465
# VAL 107 B 	0.99385498062
# VAL 107 A 	0.681603038638
# LEU 54 B 	0.229255997435
# ALA 100 A 	0.439781599175
# LEU 177 A 	0.877033747454
# LEU 177 B 	0.996849700906
# ILE 89 A 	0.571485190011
# LEU 220 A 	0.634332343223
# ILE 147 A 	0.257281209352
# ALA 50 A 	0.100351095593
# ILE 57 A 	-0.850853115434
# ALA 112 A 	0.436455715978
# ALA 201 A 	0.259885204082
# LEU 197 A 	0.128406364945
# LEU 115 A 	0.215308334443
# LEU 115 B 	0.25555134577
# ILE 24 A 	-1.37052205634
# MET 1 A WRITING GREY:
# ILE 2 A WRITING GREY:
# SER 3 A WRITING GREY:
# GLY 4 A WRITING GREY:
# ILE 5 A WRITING GREY:
# ENTERED LOOP
# LEU 6 A WRITING GREY:
# ENTERED LOOP
# LEU 6 B WRITING GREY:
# ENTERED LOOP
# ALA 7 A WRITING GREY:
# SER 8 A WRITING GREY:
# PRO 9 A WRITING GREY:
# GLY 10 A WRITING GREY:
# ENTERED LOOP
# ILE 11 A WRITING GREY:
# ENTERED LOOP
# ALA 12 A WRITING GREY:
# PHE 13 A WRITING GREY:
# GLY 14 A WRITING GREY:
# LYS 15 A WRITING GREY:
# ENTERED LOOP
# ALA 16 A WRITING GREY:
# ENTERED LOOP
# LEU 17 A WRITING GREY:
# ENTERED LOOP
# LEU 17 B WRITING GREY:
# ENTERED LOOP
# LEU 18 A WRITING GREY:
# ENTERED LOOP
# LEU 18 B WRITING GREY:
# ENTERED LOOP
# LEU 19 A WRITING GREY:
# ENTERED LOOP
# LEU 19 B WRITING GREY:
# LYS 20 A WRITING GREY:
# GLU 21 A WRITING GREY:
# ASP 22 A WRITING GREY:
# GLU 23 A WRITING GREY:
# ENTERED LOOP
# ILE 24 A WRITING GREY:
# ENTERED LOOP
# VAL 25 A WRITING GREY:
# ENTERED LOOP
# VAL 25 B WRITING GREY:
# ENTERED LOOP
# ILE 26 A WRITING GREY:
# ASP 27 A WRITING GREY:
# ARG 28 A WRITING GREY:
# LYS 29 A WRITING GREY:
# LYS 30 A WRITING GREY:
# ENTERED LOOP
# ILE 31 A WRITING GREY:
# SER 32 A WRITING GREY:
# ENTERED LOOP
# ALA 33 A WRITING GREY:
# ASP 34 A WRITING GREY:
# GLN 35 A WRITING GREY:
# ENTERED LOOP
# VAL 36 A WRITING GREY:
# ENTERED LOOP
# VAL 36 B WRITING GREY:
# ASP 37 A WRITING GREY:
# GLN 38 A WRITING GREY:
# GLU 39 A WRITING GREY:
# ENTERED LOOP
# VAL 40 A WRITING GREY:
# ENTERED LOOP
# VAL 40 B WRITING GREY:
# GLU 41 A WRITING GREY:
# ARG 42 A WRITING GREY:
# PHE 43 A WRITING GREY:
# ENTERED LOOP
# LEU 44 A WRITING GREY:
# ENTERED LOOP
# LEU 44 B WRITING GREY:
# SER 45 A WRITING GREY:
# GLY 46 A WRITING GREY:
# ARG 47 A WRITING GREY:
# ALA 48 A WRITING GREY:
# LYS 49 A WRITING GREY:
# ENTERED LOOP
# ALA 50 A WRITING GREY:
# SER 51 A WRITING GREY:
# ALA 52 A WRITING GREY:
# GLN 53 A WRITING GREY:
# ENTERED LOOP
# LEU 54 A WRITING GREY:
# ENTERED LOOP
# LEU 54 B WRITING GREY:
# GLU 55 A WRITING GREY:
# THR 56 A WRITING GREY:
# ENTERED LOOP
# ILE 57 A WRITING GREY:
# LYS 58 A WRITING GREY:
# THR 59 A WRITING GREY:
# LYS 60 A WRITING GREY:
# ENTERED LOOP
# ALA 61 A WRITING GREY:
# GLY 62 A WRITING GREY:
# GLU 63 A WRITING GREY:
# THR 64 A WRITING GREY:
# PHE 65 A WRITING GREY:
# GLY 66 A WRITING GREY:
# GLU 67 A WRITING GREY:
# GLU 68 A WRITING GREY:
# LYS 69 A WRITING GREY:
# GLU 70 A WRITING GREY:
# ENTERED LOOP
# ALA 71 A WRITING GREY:
# ENTERED LOOP
# ILE 72 A WRITING GREY:
# PHE 73 A WRITING GREY:
# GLU 74 A WRITING GREY:
# GLY 75 A WRITING GREY:
# HIS 76 A WRITING GREY:
# ENTERED LOOP
# ILE 77 A WRITING GREY:
# MET 78 A WRITING GREY:
# ENTERED LOOP
# LEU 79 A WRITING GREY:
# ENTERED LOOP
# LEU 79 B WRITING GREY:
# ENTERED LOOP
# LEU 80 A WRITING GREY:
# ENTERED LOOP
# LEU 80 B WRITING GREY:
# GLU 81 A WRITING GREY:
# ASP 82 A WRITING GREY:
# GLU 83 A WRITING GREY:
# GLU 84 A WRITING GREY:
# ENTERED LOOP
# LEU 85 A WRITING GREY:
# ENTERED LOOP
# LEU 85 B WRITING GREY:
# GLU 86 A WRITING GREY:
# GLN 87 A WRITING GREY:
# GLU 88 A WRITING GREY:
# ENTERED LOOP
# ILE 89 A WRITING GREY:
# ENTERED LOOP
# ILE 90 A WRITING GREY:
# ALA 91 A WRITING GREY:
# ENTERED LOOP
# LEU 92 A WRITING GREY:
# ENTERED LOOP
# LEU 92 B WRITING GREY:
# ENTERED LOOP
# ILE 93 A WRITING GREY:
# LYS 94 A WRITING GREY:
# ASP 95 A WRITING GREY:
# LYS 96 A WRITING GREY:
# HIS 97 A WRITING GREY:
# MET 98 A WRITING GREY:
# THR 99 A WRITING GREY:
# ENTERED LOOP
# ALA 100 A WRITING GREY:
# ASP 101 A WRITING GREY:
# ENTERED LOOP
# ALA 102 A WRITING GREY:
# ENTERED LOOP
# ALA 103 A WRITING GREY:
# ENTERED LOOP
# ALA 104 A WRITING GREY:
# HIS 105 A WRITING GREY:
# GLU 106 A WRITING GREY:
# ENTERED LOOP
# VAL 107 A WRITING GREY:
# ENTERED LOOP
# VAL 107 B WRITING GREY:
# ENTERED LOOP
# ILE 108 A WRITING GREY:
# GLU 109 A WRITING GREY:
# GLY 110 A WRITING GREY:
# GLN 111 A WRITING GREY:
# ENTERED LOOP
# ALA 112 A WRITING GREY:
# SER 113 A WRITING GREY:
# ENTERED LOOP
# ALA 114 A WRITING GREY:
# ENTERED LOOP
# LEU 115 A WRITING GREY:
# ENTERED LOOP
# LEU 115 B WRITING GREY:
# GLU 116 A WRITING GREY:
# GLU 117 A WRITING GREY:
# ENTERED LOOP
# LEU 118 A WRITING GREY:
# ENTERED LOOP
# LEU 118 B WRITING GREY:
# ASP 119 A WRITING GREY:
# ASP 120 A WRITING GREY:
# GLU 121 A WRITING GREY:
# TYR 122 A WRITING GREY:
# ENTERED LOOP
# LEU 123 A WRITING GREY:
# ENTERED LOOP
# LEU 123 B WRITING GREY:
# LYS 124 A WRITING GREY:
# GLU 125 A WRITING GREY:
# ARG 126 A WRITING GREY:
# ENTERED LOOP
# ALA 127 A WRITING GREY:
# ALA 128 A WRITING GREY:
# ASP 129 A WRITING GREY:
# ENTERED LOOP
# VAL 130 A WRITING GREY:
# ENTERED LOOP
# VAL 130 B WRITING GREY:
# ARG 131 A WRITING GREY:
# ASP 132 A WRITING GREY:
# ENTERED LOOP
# ILE 133 A WRITING GREY:
# GLY 134 A WRITING GREY:
# LYS 135 A WRITING GREY:
# ARG 136 A WRITING GREY:
# ENTERED LOOP
# LEU 137 A WRITING GREY:
# ENTERED LOOP
# LEU 137 B WRITING GREY:
# ENTERED LOOP
# LEU 138 A WRITING GREY:
# ENTERED LOOP
# LEU 138 B WRITING GREY:
# ARG 139 A WRITING GREY:
# ASN 140 A WRITING GREY:
# ENTERED LOOP
# ILE 141 A WRITING GREY:
# ENTERED LOOP
# LEU 142 A WRITING GREY:
# ENTERED LOOP
# LEU 142 B WRITING GREY:
# GLY 143 A WRITING GREY:
# LEU 144 A WRITING GREY:
# LEU 144 B WRITING GREY:
# LYS 145 A WRITING GREY:
# ILE 146 A WRITING GREY:
# ENTERED LOOP
# ILE 147 A WRITING GREY:
# ASP 148 A WRITING GREY:
# ENTERED LOOP
# LEU 149 A WRITING GREY:
# ENTERED LOOP
# LEU 149 B WRITING GREY:
# SER 150 A WRITING GREY:
# ENTERED LOOP
# ALA 151 A WRITING GREY:
# ENTERED LOOP
# ILE 152 A WRITING GREY:
# GLN 153 A WRITING GREY:
# ASP 154 A WRITING GREY:
# GLU 155 A WRITING GREY:
# ENTERED LOOP
# VAL 156 A WRITING GREY:
# ENTERED LOOP
# VAL 156 B WRITING GREY:
# ENTERED LOOP
# ILE 157 A WRITING GREY:
# ENTERED LOOP
# LEU 158 A WRITING GREY:
# ENTERED LOOP
# LEU 158 B WRITING GREY:
# ENTERED LOOP
# VAL 159 A WRITING GREY:
# ENTERED LOOP
# VAL 159 B WRITING GREY:
# ENTERED LOOP
# ALA 160 A WRITING GREY:
# ENTERED LOOP
# ALA 161 A WRITING GREY:
# ASP 162 A WRITING GREY:
# ENTERED LOOP
# LEU 163 A WRITING GREY:
# ENTERED LOOP
# LEU 163 B WRITING GREY:
# THR 164 A WRITING GREY:
# PRO 165 A WRITING GREY:
# SER 166 A WRITING GREY:
# GLU 167 A WRITING GREY:
# THR 168 A WRITING GREY:
# ENTERED LOOP
# ALA 169 A WRITING GREY:
# GLN 170 A WRITING GREY:
# LEU 171 A WRITING GREY:
# LEU 171 B WRITING GREY:
# ASN 172 A WRITING GREY:
# LEU 173 A WRITING GREY:
# LEU 173 B WRITING GREY:
# LYS 174 A WRITING GREY:
# LYS 175 A WRITING GREY:
# ENTERED LOOP
# VAL 176 A WRITING GREY:
# ENTERED LOOP
# VAL 176 B WRITING GREY:
# ENTERED LOOP
# LEU 177 A WRITING GREY:
# ENTERED LOOP
# LEU 177 B WRITING GREY:
# GLY 178 A WRITING GREY:
# PHE 179 A WRITING GREY:
# ENTERED LOOP
# ILE 180 A WRITING GREY:
# THR 181 A WRITING GREY:
# ASP 182 A WRITING GREY:
# ENTERED LOOP
# ALA 183 A WRITING GREY:
# GLY 184 A WRITING GREY:
# GLY 185 A WRITING GREY:
# ARG 186 A WRITING GREY:
# THR 187 A WRITING GREY:
# SER 188 A WRITING GREY:
# HIS 189 A WRITING GREY:
# THR 190 A WRITING GREY:
# SER 191 A WRITING GREY:
# ENTERED LOOP
# ILE 192 A WRITING GREY:
# MET 193 A WRITING GREY:
# ENTERED LOOP
# ALA 194 A WRITING GREY:
# ARG 195 A WRITING GREY:
# SER 196 A WRITING GREY:
# ENTERED LOOP
# LEU 197 A WRITING GREY:
# ENTERED LOOP
# LEU 197 B WRITING GREY:
# GLU 198 A WRITING GREY:
# ENTERED LOOP
# LEU 199 A WRITING GREY:
# ENTERED LOOP
# LEU 199 B WRITING GREY:
# PRO 200 A WRITING GREY:
# ENTERED LOOP
# ALA 201 A WRITING GREY:
# ENTERED LOOP
# ILE 202 A WRITING GREY:
# ENTERED LOOP
# VAL 203 A WRITING GREY:
# ENTERED LOOP
# VAL 203 B WRITING GREY:
# GLY 204 A WRITING GREY:
# THR 205 A WRITING GREY:
# GLY 206 A WRITING GREY:
# SER 207 A WRITING GREY:
# ENTERED LOOP
# VAL 208 A WRITING GREY:
# ENTERED LOOP
# VAL 208 B WRITING GREY:
# THR 209 A WRITING GREY:
# SER 210 A WRITING GREY:
# GLN 211 A WRITING GREY:
# ENTERED LOOP
# VAL 212 A WRITING GREY:
# ENTERED LOOP
# VAL 212 B WRITING GREY:
# LYS 213 A WRITING GREY:
# ASN 214 A WRITING GREY:
# ASP 215 A WRITING GREY:
# ASP 216 A WRITING GREY:
# TYR 217 A WRITING GREY:
# ENTERED LOOP
# LEU 218 A WRITING GREY:
# ENTERED LOOP
# LEU 218 B WRITING GREY:
# ENTERED LOOP
# ILE 219 A WRITING GREY:
# ENTERED LOOP
# LEU 220 A WRITING GREY:
# ENTERED LOOP
# LEU 220 B WRITING GREY:
# ASP 221 A WRITING GREY:
# ALA 222 A WRITING GREY:
# ENTERED LOOP
# VAL 223 A WRITING GREY:
# ENTERED LOOP
# VAL 223 B WRITING GREY:
# ASN 224 A WRITING GREY:
# ASN 225 A WRITING GREY:
# GLN 226 A WRITING GREY:
# ENTERED LOOP
# VAL 227 A WRITING GREY:
# ENTERED LOOP
# VAL 227 B WRITING GREY:
# TYR 228 A WRITING GREY:
# ENTERED LOOP
# VAL 229 A WRITING GREY:
# ENTERED LOOP
# VAL 229 B WRITING GREY:
# ASN 230 A WRITING GREY:
# PRO 231 A WRITING GREY:
# THR 232 A WRITING GREY:
# ASN 233 A WRITING GREY:
# GLU 234 A WRITING GREY:
# ENTERED LOOP
# VAL 235 A WRITING GREY:
# ENTERED LOOP
# VAL 235 B WRITING GREY:
# ENTERED LOOP
# ILE 236 A WRITING GREY:
# ASP 237 A WRITING GREY:
# LYS 238 A WRITING GREY:
# MET 239 A WRITING GREY:
# ARG 240 A WRITING GREY:
# ENTERED LOOP
# ALA 241 A WRITING GREY:
# ENTERED LOOP
# VAL 242 A WRITING GREY:
# ENTERED LOOP
# VAL 242 B WRITING GREY:
# GLN 243 A WRITING GREY:
# GLU 244 A WRITING GREY:
# GLN 245 A WRITING GREY:
# ENTERED LOOP
# VAL 246 A WRITING GREY:
# ENTERED LOOP
# VAL 246 B WRITING GREY:
# ENTERED LOOP
# ALA 247 A WRITING GREY:
# SER 248 A WRITING GREY:
# GLU 249 A WRITING GREY:
# LYS 250 A WRITING GREY:
# ALA 251 A WRITING GREY:
# GLU 252 A WRITING GREY:
# LEU 253 A WRITING GREY:
# LEU 253 B WRITING GREY:
# ALA 254 A WRITING GREY:
# LYS 255 A WRITING GREY:
# LEU 256 A WRITING GREY:
# LEU 256 B WRITING GREY:
# LYS 257 A WRITING GREY:
# ASP 258 A WRITING GREY:
# ARG 259 A WRITING GREY:
