# %%
# %matplotlib inline
# %run ./py/commTest.py
# Out:
# output/eps/cross_latex.tex
# Including dipolar H2 C1
# Including dipolar H3 C1
# Including dipolar H4 C1
# Including dipolar H6 C5
# Including dipolar H7 C5
# Including dipolar H8 C5
# Including dipolar H2 H3
# Including dipolar H2 H4
# Including dipolar H3 H4
# Including dipolar H6 H7
# Including dipolar H6 H8
# Including dipolar H7 H8
# Including CSA H2
# Including CSA H3
# Including CSA H4
# Including CSA H6
# Including CSA H7
# Including CSA H8
# Including CSA C1
# Including CSA C5
# Including dipolar H2 H6
# Including dipolar H2 H7
# Including dipolar H2 H8
# Including dipolar H3 H6
# Including dipolar H3 H7
# Including dipolar H3 H8
# Including dipolar H4 H6
# Including dipolar H4 H7
# Including dipolar H4 H8
# Library entries to evaluate: 16941
# NUMBER OF PEAKS INCLUDED IN OPTIMIZATION:  211
# NUMBER OF RESIDUES INCLUDED IN WOBBLE-MASK: 73.0
# NUMBER OF PEAKS INCLUDED IN DATA SET MASK: 467
# input/1EZA.pdb
# count_leu =  29
# count_val =  17
# count_ile =  24
# ...
